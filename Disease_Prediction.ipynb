# %% [markdown]
# <a href="https://colab.research.google.com/github/joseph2022/Disease-Prediction/blob/main/Disease_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DISEASE PREDICTION

# %%
# !git clone https://github.com/joseph2022/Disease-Prediction.git
# %cd Disease-Prediction
# Out:
# Cloning into 'Disease-Prediction'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 8.51 KiB | 8.51 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/Disease-Prediction

# %%
# !mv /content/Disease_Prediction.ipynb /content/Disease-Prediction/
# Out:
# mv: cannot stat '/content/Disease_Prediction.ipynb': No such file or directory

# %%
# !pwd
# Out:
# /content/Disease-Prediction

# %%
# !touch Disease_Prediction.ipynb

# %%
# !ls
# Out:
# Disease_Prediction.ipynb  README.md

# %%
# !git add Disease_Prediction.ipynb

# %%
# !git commit -m "Day 1: Created project notebook inside repository"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@029c150483a2.(none)')

# %%
# !git config --global user.name "Joseph S Ottathil"
# !git config --global user.email "josephsottathil@gmail.com"

# %%
# !git config --global user.name
# !git config --global user.email
# Out:
# Joseph S Ottathil
# josephsottathil@gmail.com

# %%
# !git add .
# !git commit -m "Day 1: Created project notebook inside repository"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# Importing Required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# load dataset
data=pd.read_csv('/content/drive/MyDrive/Disease_Prediction/heart_disease.csv')
data
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0     56.0    Male           153.0              155.0            High     Yes
# 1     69.0  Female           146.0              286.0            High      No
# 2     46.0    Male           126.0              216.0             Low      No
# 3     32.0  Female           122.0              293.0            High     Yes
# 4     60.0    Male           166.0              242.0             Low     Yes
# ...    ...     ...             ...                ...             ...     ...
# 9995  25.0  Female           136.0              243.0          Medium     Yes
# 9996  38.0    Male           172.0              154.0          Medium      No
# 9997  73.0    Male           152.0              201.0            High     Yes
# 9998  23.0    Male           142.0              299.0             Low     Yes
# 9999  38.0  Female           128.0              193.0          Medium     Yes
#
# ...

# %%
data.shape # returns the number of rows and columns(dimensions of the dataframe)
# Out:
# (10000, 21)

# %%
data.dtypes
# Out:
# Age                     float64
# Gender                   object
# Blood Pressure          float64
# Cholesterol Level       float64
# Exercise Habits          object
# Smoking                  object
# Family Heart Disease     object
# Diabetes                 object
# BMI                     float64
# High Blood Pressure      object
# Low HDL Cholesterol      object
# High LDL Cholesterol     object
# Alcohol Consumption      object
# Stress Level             object
# Sleep Hours             float64
# Sugar Consumption        object
# Triglyceride Level      float64
# Fasting Blood Sugar     float64
# CRP Level               float64
# Homocysteine Level      float64
# Heart Disease Status     object
# dtype: object

# %%
data.isna().sum()
# Out:
# Age                       29
# Gender                    19
# Blood Pressure            19
# Cholesterol Level         30
# Exercise Habits           25
# Smoking                   25
# Family Heart Disease      21
# Diabetes                  30
# BMI                       22
# High Blood Pressure       26
# Low HDL Cholesterol       25
# High LDL Cholesterol      26
# Alcohol Consumption     2586
# Stress Level              22
# Sleep Hours               25
# Sugar Consumption         30
# Triglyceride Level        26
# Fasting Blood Sugar       22
# CRP Level                 26
# Homocysteine Level        20
# Heart Disease Status       0
# dtype: int64

# %%
# Dropped Alcohol Consumption due to high missing value
data.drop('Alcohol Consumption',axis=1)
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0     56.0    Male           153.0              155.0            High     Yes
# 1     69.0  Female           146.0              286.0            High      No
# 2     46.0    Male           126.0              216.0             Low      No
# 3     32.0  Female           122.0              293.0            High     Yes
# 4     60.0    Male           166.0              242.0             Low     Yes
# ...    ...     ...             ...                ...             ...     ...
# 9995  25.0  Female           136.0              243.0          Medium     Yes
# 9996  38.0    Male           172.0              154.0          Medium      No
# 9997  73.0    Male           152.0              201.0            High     Yes
# 9998  23.0    Male           142.0              299.0             Low     Yes
# 9999  38.0  Female           128.0              193.0          Medium     Yes
#
# ...

# %%
# a=data.Age.mean() # Another method
# a

# %%
#ata.Age=data.Age.fillna(a)

# %%
# identify numerical,categorical columns
numerical_cols=data.select_dtypes(include=['int64','float64']).columns
categorical_cols=data.select_dtypes(include=['object']).columns

# fill numerical columns with median, we can also do it with mean and also mode too.
for col in numerical_cols:
  data[col]=data[col].fillna(data[col].median())

# fill categorical columns with median, we can also do it with mean and also mode too.
for col in categorical_cols:
  data[col]=data[col].fillna(data[col].mode()[0])

data.isna().sum()
# Out:
# Age                     0
# Gender                  0
# Blood Pressure          0
# Cholesterol Level       0
# Exercise Habits         0
# Smoking                 0
# Family Heart Disease    0
# Diabetes                0
# BMI                     0
# High Blood Pressure     0
# Low HDL Cholesterol     0
# High LDL Cholesterol    0
# Alcohol Consumption     0
# Stress Level            0
# Sleep Hours             0
# Sugar Consumption       0
# Triglyceride Level      0
# Fasting Blood Sugar     0
# CRP Level               0
# Homocysteine Level      0
# Heart Disease Status    0
# dtype: int64
